# %% [markdown]
# <h1 style=background-color:purple;color:white;font-family:'sans-serif';text-align:center>HEART DISEASE</h1>

# %% [markdown]
# <h3>Importing libraries</h3>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
np.__version__
# Out:
# '1.26.4'

# %%
data = pd.read_csv(r'H:\sir daily notes tasks-oct\30th- Seaborn, Eda practicle\EDA\heart.csv')

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# <h3>Basic info of data</h3>

# %%
data.shape
# Out:
# (303, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# <h3>Finding Duplicates</h3>

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data[data.duplicated()]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 164      2   4     2       1

# %%
data[164:170]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 164   38    1   2       138   175    0        1      173      0      0.0
# 165   67    1   0       160   286    0        0      108      1      1.5
# 166   67    1   0       120   229    0        0      129      1      2.6
# 167   62    0   0       140   268    0        0      160      0      3.6
# 168   63    1   0       130   254    0        0      147      0      1.4
# 169   53    1   0       140   203    1        0      155      1      3.1
#
#      slope  ca  thal  target
# 164      2   4     2       1
# 165      1   3     2       0
# 166      1   2     3       0
# 167      0   2     2       0
# 168      1   1     3       0
# 169      0   0     3       0

# %%
data[data['age']==38]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 163   38    1   2       138   175    0        1      173      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
# 259   38    1   3       120   231    0        1      182      1      3.8
#
#      slope  ca  thal  target
# 163      2   4     2       1
# 164      2   4     2       1
# 259      1   0     3       0

# %% [markdown]
# <p>In this Dataset, there is an one duplicate record existed which is 163==164</p>

# %% [markdown]
# <h3>Removing Duplicate record</h3>

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data[163:165]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 163   38    1   2       138   175    0        1      173      0      0.0
# 165   67    1   0       160   286    0        0      108      1      1.5
#
#      slope  ca  thal  target
# 163      2   4     2       1
# 165      1   3     2       0

# %% [markdown]
# <p>Here we can see the duplicate record was removed</p>

# %% [markdown]
# <h5>Now,the data has no null values,duplicates and raw data</h5>

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# <h5>Here Feature/Target variable is <code>target</code>.it tells who have the heart disease and no heart disease</h5>

# %% [markdown]
# <h4>Now,We will start the Visualizations</h4>

# %%
plt.rcParams['figure.figsize']=(10,7)

# %%
data['target'].nunique()
# Out:
# 2

# %%
data['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# <p><bold>164 members have the heart disease , 138 members don't have the heart disease</bold></p>

# %%
data.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          92
# Name: count, dtype: int64

# %% [markdown]
# <p>sex : 1-->male
# 0-->female</p>
# <p>target : 0-->no heart disease
# 1-->heart disease</p>

# %% [markdown]
# <p><bold>In females <code>71</code> members have the heart disease and <code>24</code> don't have.In males <code>114</code> members have the heart disease and <code>92</code> haven't the heart disease </bold></p>

# %%
f,ax=plt.subplots(figsize=(10,7))
ax = sns.countplot(x='target',hue='target',data=data)
plt.legend(title='Heart disease')
plt.show()

# %% [markdown]
# <p><bold>target--><code>1</code>==who has the heart disease, <code>0</code>==who hasn't the heart disease</bold></p>

# %%
f,ax=plt.subplots(figsize=(10,7))
ax = sns.countplot(x='target',hue='sex',data=data)
plt.legend(title='sex')
plt.show()

# %%
ax = sns.catplot(x="target", col="sex",hue='target', data=data, kind="count", height=5, aspect=1)

# %%
sns.set(style='whitegrid')
sns.barplot(x='target',y='chol',hue='target',data=data)
plt.legend(loc=1)
plt.xlabel('target')
plt.ylabel('chol')
plt.title('target vs chol')
# Out:
# Text(0.5, 1.0, 'target vs chol')

# %%
sns.barplot(data=data,y='age',x='target',hue='sex')
plt.xticks([0,1])
plt.show()

# %%
data['age'].min()
# Out:
# 29

# %%
sns.boxplot(y='age',x='sex',hue='target',data=data)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# <p>the heart disease has been getting at the age of 50 - 60 yrs.this is average</p>

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(y="target", hue="sex", data=data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", data=data, palette="Set2")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", data=data, facecolor=(0, 0, 0, 0), linewidth=5, edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", hue="fbs", data=data)
plt.show() #fbs (fasting blood sugar) and exang (exercise induced angina).

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", hue="exang", data=data)
plt.show()

# %% [markdown]
# <h3>Finding correlation</h3>

# %%
correlation = data.corr()

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.432080
# thalach     0.419955
# slope       0.343940
# restecg     0.134874
# fbs        -0.026826
# chol       -0.081437
# trestbps   -0.146269
# age        -0.221476
# sex        -0.283609
# thal       -0.343101
# ca         -0.408992
# oldpeak    -0.429146
# exang      -0.435601
# Name: target, dtype: float64

# %% [markdown]
# ### correalation ranges from -1 to +1
#
# - when it is close to -1 , this signifies that there is a strong negative correlation
# - when it is close to +1 , this signifies that there is a strong positive correlation
# - when it is close to 0 , this signifies that there is a no correlation

# %%
data['age'].nunique()
# Out:
# 41

# %%
data['age'].value_counts()
# Out:
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 62    11
# 56    11
# 44    11
# 60    11
# 41    10
# 64    10
# 67     9
# 63     9
# 43     8
# 55     8
# 42     8
# 61     8
# 65     8
# 53     8
# 45     8
# 50     7
# 48     7
# 46     7
# 66     7
# 47     5
# 49     5
# 70     4
# 39     4
# 68     4
# 35     4
# 71     3
# 40     3
# 69     3
# 34     2
# 37     2
# 38     2
# 29     1
# 74     1
# 76     1
# 77     1
# Name: count, dtype: int64

# %% [markdown]
# ## Analysis of age and target variable

# %%
data['age'].describe()
# Out:
# count    302.00000
# mean      54.42053
# std        9.04797
# min       29.00000
# 25%       48.00000
# 50%       55.50000
# 75%       61.00000
# max       77.00000
# Name: age, dtype: float64

# %%
sns.boxplot(x='target',y='age',hue='sex',data=data)
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
f, ax=plt.subplots(figsize=(10,7))
ax=sns.countplot(x='target',hue='age',data=data)

# %% [markdown]
# - below 60 age people have got the heart diseases
# - and mostly 50 - 60 age people have got this disease.

# %%
g = sns.FacetGrid(data,row='sex',col='target',hue = 'sex')
g= g.map(plt.hist,'age',bins=20)

# %%
f, ax = plt.subplots(figsize=(10,6))
x = data['age']
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="age", data=data,hue='target')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="target", y="age", data=data,hue='target')
plt.show()

# %% [markdown]
# ## CP

# %%
data['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     86
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
data['cp'].nunique()
# Out:
# 4

# %%
data['cp'].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
data['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     86
# 1     50
# 3     23
# Name: count, dtype: int64

# %% [markdown]
# <p>Chest pain <code>cp</code> has the four types : 0,1,2,3</p>

# %% [markdown]
# <h4>Frequency of the cp variable</h4>

# %%
f,ax = plt.subplots(figsize=(10,7))
ax=sns.countplot(x='cp',data=data,hue='cp')
plt.show()

# %% [markdown]
# <h3>Analysis of <code>target</code> and <code>cp</code> varible</h3>

# %%
data.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          68
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="cp", hue="target", data=data)
plt.show()

# %%
ax = sns.catplot(x="target", col="cp", data=data,hue='target', kind="count", height=8, aspect=1)

# %% [markdown]
# <h3>Analysis of <code>target</code> and <code>thalach</code> variable</h3>

# %%
data['thalach'].nunique()
# Out:
# 91

# %%
data['thalach'].unique()
# Out:
# array([150, 187, 172, 178, 163, 148, 153, 173, 162, 174, 160, 139, 171,
#        144, 158, 114, 151, 161, 179, 137, 157, 123, 152, 168, 140, 188,
#        125, 170, 165, 142, 180, 143, 182, 156, 115, 149, 146, 175, 186,
#        185, 159, 130, 190, 132, 147, 154, 202, 166, 164, 184, 122, 169,
#        138, 111, 145, 194, 131, 133, 155, 167, 192, 121,  96, 126, 105,
#        181, 116, 108, 129, 120, 112, 128, 109, 113,  99, 177, 141, 136,
#         97, 127, 103, 124,  88, 195, 106,  95, 117,  71, 118, 134,  90],
#       dtype=int64)

# %% [markdown]
# #### Visualize the frequency distribution of `thalach` variable

# %%
f,ax=plt.subplots(figsize=(10,6))
x=data['thalach']
ax=sns.distplot(x,bins=10)
plt.show()

# %% [markdown]
# - we can see that the thalch is slightly negatively skewed.

# %%
# here we can use the pd.series
f, ax = plt.subplots(figsize=(10,6))
x = data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.distplot(x, bins=10)
plt.show()

# %%
# vertical axis
f, ax = plt.subplots(figsize=(10,6))
x = data['thalach']
ax = sns.distplot(x, bins=10, vertical=True)
plt.show()

# %% [markdown]
# ## Seaborn Kernel Density Estimation(KDE) Plot
# - KDE is a useful tool for plotting the shape of a distribution

# %%
f, ax = plt.subplots(figsize=(10,6))
x = data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x, shade=True, color='r')
plt.show()

# %%
# Histogram
f, ax = plt.subplots(figsize=(10,6))
x = data['thalach']
ax = sns.distplot(x, kde=False, rug=True, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="thalach", data=data,hue='target')
plt.show()

# %% [markdown]
# - we can see that those people suffering from heart disease(target=1) have relatively higher heart rate (thalach) as compared to people who are not suffering from heart disease (target=0)

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="thalach", data=data, jitter = 0.01,hue='target')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="target", y="thalach", data=data,hue='target')
plt.show()

# %% [markdown]
# ### Discover patterns and relationships
#
# - An important step in EDA is to discover patterns and relationships between variables in the dataset.
#
# - I will use `heat map` and `pair plot` to discover the patterns and relationships in the dataset.
#
# - First of all, I will draw a `heat map`.

# %% [markdown]
# # Heat Map

# %%
plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Heart Disease Dataset')
a = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %% [markdown]
# #### Interpretation
#
# From the above correlation heat map, we can conclude that :-
#
# - `target` and `cp` variable are mildly positively correlated (correlation coefficient = 0.43).
#
# - `target` and `thalach` variable are also mildly positively correlated (correlation coefficient = 0.42).
#
# - `target` and `slope` variable are weakly positively correlated (correlation coefficient = 0.35).
#
# - `target` and `exang` variable are mildly negatively correlated (correlation coefficient = -0.44).
#
# - `target` and `oldpeak` variable are also mildly negatively correlated (correlation coefficient = -0.43).
#
# - `target` and `ca` variable are weakly negatively correlated (correlation coefficient = -0.39).
#
# - `target` and `thal` variable are also waekly negatively correlated (correlation coefficient = -0.34).

# %% [markdown]
# ## Pair Plot

# %%
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.pairplot(data[num_var], kind='scatter', diag_kind='hist')
plt.show()

# %% [markdown]
# # Analyze the age and trestbps

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x="age", y="trestbps", data=data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="age", y="trestbps", data=data)
plt.show()

# %% [markdown]
# #### Interpretation
#
# - The above line shows that linear regression model is not good fit to the data.

# %% [markdown]
# ### Analyze `age` and `chol` variable

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x="age", y="chol", data=data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="age", y="chol", data=data)
plt.show()

# %% [markdown]
# #### Interpretation
#
# - The above plot confirms that there is a slighly positive correlation between `age` and `chol` variables.

# %% [markdown]
# ### Analyze `chol` and `thalach` variable

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x="chol", y = "thalach", data=data,hue='target')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="chol", y="thalach", data=data)
plt.show()

# %% [markdown]
# #### Interpretation
#
#
# - The above plot shows that there is no correlation between `chol` and `thalach` variable.

# %% [markdown]
# # Check with ASSERT statement

# %%
assert pd.notnull(data).all().all()

# %%
assert (data >= 0).all().all()

# %% [markdown]
# **Assert statement** will return nothing if the value being tested is true and will throw an AssertionError if the value is false.
# - **Asserts**
#
#   - assert 1 == 1 (return Nothing if the value is True)
#
#   - assert 1 == 2 (return AssertionError if the value is False)

# %% [markdown]
# #### Interpretation
#
# - The above two commands do not throw any error. Hence, it is confirmed that there are no missing or negative values in the dataset.
#
# - All the values are greater than or equal to zero.

# %% [markdown]
# # Outlier detection

# %% [markdown]
# I will make boxplots to visualise outliers in the continuous numerical variables : -
#
# `age`, `trestbps`, `chol`, `thalach` and  `oldpeak` variables.

# %% [markdown]
# ### `age` variable

# %%
data['age'].describe()
# Out:
# count    302.00000
# mean      54.42053
# std        9.04797
# min       29.00000
# 25%       48.00000
# 50%       55.50000
# 75%       61.00000
# max       77.00000
# Name: age, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=data["age"])
plt.show()

# %%
data['trestbps'].describe()
# Out:
# count    302.000000
# mean     131.602649
# std       17.563394
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=data["trestbps"])
plt.show()

# %%
data['chol'].describe()
# Out:
# count    302.000000
# mean     246.500000
# std       51.753489
# min      126.000000
# 25%      211.000000
# 50%      240.500000
# 75%      274.750000
# max      564.000000
# Name: chol, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=data["chol"])
plt.show()

# %%
data['thalach'].describe()
# Out:
# count    302.000000
# mean     149.569536
# std       22.903527
# min       71.000000
# 25%      133.250000
# 50%      152.500000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=data["thalach"])
plt.show()

# %%
data['oldpeak'].describe()
# Out:
# count    302.000000
# mean       1.043046
# std        1.161452
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=data["oldpeak"])
plt.show()

# %% [markdown]
# #### Findings
#
# - The `age` variable does not contain any outlier.
#
# - `trestbps` variable contains outliers to the right side.
#
# - `chol` variable also contains outliers to the right side.
#
# - `thalach` variable contains a single outlier to the left side.
#
# - `oldpeak` variable contains outliers to the right side.
#
# - Those variables containing outliers needs further investigation.
